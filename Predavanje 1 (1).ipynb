# %% [markdown]
# # Zadatak 1
# Ovdje ide tekst zadatka

# %%
print("Sead")
# Out:
# Sead

# %% [markdown]
# # Zadatak 2
# Ovdje ide drugi zadatak

# %%
x = int(input())
print(x+12)
# Out:
# 23
# 35

# %% [markdown]
# ## Zadatak 3
# Korisnik unosi x ispisi 2x

# %%
x = int(input())
print(x*2)
# Out:
# 313
# 626
